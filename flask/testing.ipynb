# %%
import utils.image as im_utils

# %%
jpg = "static/portraits/_example.jpg"

# %%
# take a peek at example portrait

im = im_utils.load_image(jpg)
im_nat = im_utils.natural_color(im)

im_utils.display_image(im_nat)

# %%
# image -> foreground mask

_, im_mask = im_utils.foreground_extractor(image=im, rectangle=(500, 0, 2500, 2200))

# %%
im_utils.display_image(im_mask)
